# %% [markdown]
# # Exploring Ranking Models in Information Retrieval
#
# ## Objective
# Understand the practical implementation and differences between the Vector Space Model and the Binary Independence Model in ranking documents relative to a user query.

# %% [markdown]
# ### Step 1: Data Preprocessing
#
# Ensure that the documents are still loaded and preprocessed from the previous task. The data should be clean and ready for advanced querying.
# Write a function to load and preprocess the text documents from a specified directory. This step involves reading each file, converting the text to lowercase for uniform processing, and storing the results in a dictionary.

# %% [markdown]
# # LIBRERIAS

# %%
import os
import re
import collections
import pandas as pd
from numpy import dot
from numpy.linalg import norm
import numpy as np

# %%
# Define the path to the directory containing the text files
CORPUS_DIR = "../week01/data"
documents = {}

# %%
def clean_text(text):
    # Remover símbolos y paréntesis utilizando expresiones regulares
    cleaned_text = re.sub(r'[^\w\s]', '', text)
    return cleaned_text

for filename in os.listdir(CORPUS_DIR):
    if filename.endswith('.txt'):
        file_path = os.path.join(CORPUS_DIR, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read().lower()
            cleaned_text = clean_text(text)
            documents[filename] = cleaned_text

# %%
# Dictionary to save the doc normalized
normalized_word_counts = {}

# %%
for doc in documents:
    word_count = collections.Counter(documents[doc].split())
    total_words = sum(word_count.values())
    normalized_word_count = {word: count/total_words for word, count in word_count.items()}
    normalized_word_counts[doc] = normalized_word_count

# %%
df = pd.DataFrame.from_dict(normalized_word_counts)

# %%
df_no_nan = df.fillna(0)
df_no_nan = df_no_nan.rename_axis('Files')
df_no_nan.head(10)
# Out:
#            20_hrs_40_min_.txt  Adventures_of_Huckleberry_Finn.txt  \
# Files
# the                  0.065397                            0.044282
# project              0.002223                            0.000780
# gutenberg            0.002103                            0.000762
# ebook                0.000338                            0.000114
# of                   0.031804                            0.015634
# 20                   0.000242                            0.000009
# hrs                  0.000218                            0.000000
# 40                   0.000218                            0.000000
# min                  0.000193                            0.000000
# our                  0.002586                            0.000946
#
#            Alices_Adventures_in_Wonderland.txt  \
# Files
# the                                   0.061879
# project                               0.002984
# gutenberg                             0.002950
# ebook                                 0.000441
# of                                    0.021395
# 20                                    0.000034
# hrs                                   0.000000
# 40                                    0.000000
# min                                   0.000000
# our                                   0.000407
#
#            Ang_Filibusterismo_Karugtóng_ng_Noli_Me_Tangere.txt  \
# Files
# the                                                 0.001607
# project                                             0.000753
# gutenberg                                           0.000744
# ebook                                               0.000110
# of                                                  0.001049
# 20                                                  0.000017
# hrs                                                 0.000000
# 40                                                  0.000000
# min                                                 0.000000
# our                                                 0.000034
#
#            Anne_of_Green_Gables.txt  \
# Files
# the                        0.038739
# project                    0.000853
# gutenberg                  0.000824
# ebook                      0.000123
# of                         0.019280
# 20                         0.000009
# hrs                        0.000000
# 40                         0.000000
# min                        0.000000
# our                        0.000654
#
#            A_Christmas_Carol_in_Prose_Being_a_Ghost_Story_of_Christmas.txt  \
# Files
# the                                                 0.055549
# project                                             0.002785
# gutenberg                                           0.002754
# ebook                                               0.000411
# of                                                  0.024815
# 20                                                  0.000032
# hrs                                                 0.000000
# 40                                                  0.000000
# min                                                 0.000000
# our                                                 0.000601
#
#            A_Dolls_House__a_play.txt  A_Modest_Proposal.txt  \
# Files
# the                         0.033005               0.055297
# project                     0.002982               0.013824
# gutenberg                   0.002948               0.013514
# ebook                       0.000441               0.002019
# of                          0.017926               0.040230
# 20                          0.000034               0.000155
# hrs                         0.000000               0.000000
# 40                          0.000000               0.000000
# min                         0.000000               0.000000
# our                         0.001220               0.004039
#
#            A_Room_with_a_View.txt  A_Study_in_Scarlet.txt  ...  \
# Files                                                      ...
# the                      0.046823                0.058548  ...
# project                  0.001264                0.001894  ...
# gutenberg                0.001250                0.001873  ...
# ebook                    0.000187                0.000280  ...
# of                       0.020841                0.028714  ...
# 20                       0.000014                0.000022  ...
# hrs                      0.000000                0.000000  ...
# 40                       0.000000                0.000000  ...
# min                      0.000000                0.000000  ...
# our                      0.001005                0.001485  ...
#
#            Thus_Spake_Zarathustra_A_Book_for_All_and_None.txt  \
# Files
# the                                                 0.053015
# project                                             0.000772
# gutenberg                                           0.000764
# ebook                                               0.000114
# of                                                  0.025398
# 20                                                  0.000088
# hrs                                                 0.000000
# 40                                                  0.000000
# min                                                 0.000000
# our                                                 0.001009
#
#            Tractatus Logico-Philosophicus.txt  Treasure_Island.txt  \
# Files
# the                                  0.045192             0.064093
# project                              0.001716             0.001234
# gutenberg                            0.000585             0.001220
# ebook                                0.000273             0.000182
# of                                   0.028282             0.025306
# 20                                   0.000020             0.000028
# hrs                                  0.000000             0.000000
# 40                                   0.000020             0.000014
# min                                  0.000000             0.000000
# our                                  0.000839             0.002006
#
#            Twenty_years_after.txt  Ulysses.txt  \
# Files
# the                      0.059102     0.056060
# project                  0.000400     0.000351
# gutenberg                0.000363     0.000329
# ebook                    0.000073     0.000052
# of                       0.025328     0.030836
# 20                       0.000004     0.000056
# hrs                      0.000000     0.000000
# 40                       0.000000     0.000015
# min                      0.000000     0.000000
# our                      0.001461     0.001094
#
#            Up_the_Orinoco_and_down_the_Magdalena.txt  \
# Files
# the                                         0.079774
# project                                     0.000631
# gutenberg                                   0.000573
# ebook                                       0.000084
# of                                          0.048698
# 20                                          0.000032
# hrs                                         0.000000
# 40                                          0.000019
# min                                         0.000000
# our                                         0.005664
#
#            Walden_and_On_The_Duty_Of_Civil_Disobedience.txt  \
# Files
# the                                                0.063312
# project                                            0.000741
# gutenberg                                          0.000732
# ebook                                              0.000109
# of                                                 0.030444
# 20                                                 0.000008
# hrs                                                0.000000
# 40                                                 0.000000
# min                                                0.000000
# our                                                0.002627
#
#            War_and_Peace.txt  WinniethePooh.txt  Wuthering_Heights.txt
# Files
# the                 0.061084           0.034676               0.039849
# project             0.000178           0.003402               0.000765
# gutenberg           0.000154           0.003363               0.000732
# ebook               0.000023           0.000503               0.000109
# of                  0.026490           0.020141               0.019697
# 20                  0.000007           0.000039               0.000008
# hrs                 0.000000           0.000000               0.000000
# 40                  0.000002           0.000000               0.000000
# min                 0.000000           0.000000               0.000000
# our                 0.001102           0.000271               0.000967
#
# [10 rows x 100 columns]

# %%
df_no_nan.to_csv("vect_normalized.csv",index=True)

# %% [markdown]
# ### Step 2:  Vector Space Model (VSM)
#
# Task: Implement a simple Vector Space Model using term frequency.
#
# Requirements:
# * _Document and Query Representation:_ Convert each document and the query into a vector where each dimension corresponds to a term from the corpus. Use simple term frequency for weighting.
# * _Cosine Similarity Calculation:_ Calculate the cosine similarity between the query vector and each document vector.
# * _Ranking:_ Rank the documents based on their cosine similarity scores from highest to lowest.

# %%
df = pd.read_csv("vect_normalized.csv")

# %%
import math
def euclidean_distance(vector1, vector2):
    squared_diff = sum([(x - y)**2 for x, y in zip(vector1, vector2)])
    distance = math.sqrt(squared_diff)
    return distance

# %%
def get_query_vector(query):
    query_vector = df.loc[df['Files'] == query].values[0][1:]
    return query_vector

# %%
def rank_documents(query):
    query_vector = get_query_vector(query)
    similarities = []

    for i in range(df.shape[1] - 1):
        doc_vector = df.iloc[:, i + 1].values
        distance = euclidean_distance(query_vector, doc_vector)
        similarities.append((df.columns[i + 1], distance))

    ranked_documents = sorted(similarities, key=lambda x: x[1])
    return ranked_documents

# %%
df.head(10)
# Out:
#        Files  20_hrs_40_min_.txt  Adventures_of_Huckleberry_Finn.txt  \
# 0        the            0.065397                            0.044282
# 1    project            0.002223                            0.000780
# 2  gutenberg            0.002103                            0.000762
# 3      ebook            0.000338                            0.000114
# 4         of            0.031804                            0.015634
# 5         20            0.000242                            0.000009
# 6        hrs            0.000218                            0.000000
# 7         40            0.000218                            0.000000
# 8        min            0.000193                            0.000000
# 9        our            0.002586                            0.000946
#
#    Alices_Adventures_in_Wonderland.txt  \
# 0                             0.061879
# 1                             0.002984
# 2                             0.002950
# 3                             0.000441
# 4                             0.021395
# 5                             0.000034
# 6                             0.000000
# 7                             0.000000
# 8                             0.000000
# 9                             0.000407
#
#    Ang_Filibusterismo_Karugtóng_ng_Noli_Me_Tangere.txt  \
# 0                                           0.001607
# 1                                           0.000753
# 2                                           0.000744
# 3                                           0.000110
# 4                                           0.001049
# 5                                           0.000017
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.000034
#
#    Anne_of_Green_Gables.txt  \
# 0                  0.038739
# 1                  0.000853
# 2                  0.000824
# 3                  0.000123
# 4                  0.019280
# 5                  0.000009
# 6                  0.000000
# 7                  0.000000
# 8                  0.000000
# 9                  0.000654
#
#    A_Christmas_Carol_in_Prose_Being_a_Ghost_Story_of_Christmas.txt  \
# 0                                           0.055549
# 1                                           0.002785
# 2                                           0.002754
# 3                                           0.000411
# 4                                           0.024815
# 5                                           0.000032
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.000601
#
#    A_Dolls_House__a_play.txt  A_Modest_Proposal.txt  A_Room_with_a_View.txt  \
# 0                   0.033005               0.055297                0.046823
# 1                   0.002982               0.013824                0.001264
# 2                   0.002948               0.013514                0.001250
# 3                   0.000441               0.002019                0.000187
# 4                   0.017926               0.040230                0.020841
# 5                   0.000034               0.000155                0.000014
# 6                   0.000000               0.000000                0.000000
# 7                   0.000000               0.000000                0.000000
# 8                   0.000000               0.000000                0.000000
# 9                   0.001220               0.004039                0.001005
#
#    ...  Thus_Spake_Zarathustra_A_Book_for_All_and_None.txt  \
# 0  ...                                           0.053015
# 1  ...                                           0.000772
# 2  ...                                           0.000764
# 3  ...                                           0.000114
# 4  ...                                           0.025398
# 5  ...                                           0.000088
# 6  ...                                           0.000000
# 7  ...                                           0.000000
# 8  ...                                           0.000000
# 9  ...                                           0.001009
#
#    Tractatus Logico-Philosophicus.txt  Treasure_Island.txt  \
# 0                            0.045192             0.064093
# 1                            0.001716             0.001234
# 2                            0.000585             0.001220
# 3                            0.000273             0.000182
# 4                            0.028282             0.025306
# 5                            0.000020             0.000028
# 6                            0.000000             0.000000
# 7                            0.000020             0.000014
# 8                            0.000000             0.000000
# 9                            0.000839             0.002006
#
#    Twenty_years_after.txt  Ulysses.txt  \
# 0                0.059102     0.056060
# 1                0.000400     0.000351
# 2                0.000363     0.000329
# 3                0.000073     0.000052
# 4                0.025328     0.030836
# 5                0.000004     0.000056
# 6                0.000000     0.000000
# 7                0.000000     0.000015
# 8                0.000000     0.000000
# 9                0.001461     0.001094
#
#    Up_the_Orinoco_and_down_the_Magdalena.txt  \
# 0                                   0.079774
# 1                                   0.000631
# 2                                   0.000573
# 3                                   0.000084
# 4                                   0.048698
# 5                                   0.000032
# 6                                   0.000000
# 7                                   0.000019
# 8                                   0.000000
# 9                                   0.005664
#
#    Walden_and_On_The_Duty_Of_Civil_Disobedience.txt  War_and_Peace.txt  \
# 0                                          0.063312           0.061084
# 1                                          0.000741           0.000178
# 2                                          0.000732           0.000154
# 3                                          0.000109           0.000023
# 4                                          0.030444           0.026490
# 5                                          0.000008           0.000007
# 6                                          0.000000           0.000000
# 7                                          0.000000           0.000002
# 8                                          0.000000           0.000000
# 9                                          0.002627           0.001102
#
#    WinniethePooh.txt  Wuthering_Heights.txt
# 0           0.034676               0.039849
# 1           0.003402               0.000765
# 2           0.003363               0.000732
# 3           0.000503               0.000109
# 4           0.020141               0.019697
# 5           0.000039               0.000008
# 6           0.000000               0.000000
# 7           0.000000               0.000000
# 8           0.000000               0.000000
# 9           0.000271               0.000967
#
# [10 rows x 101 columns]

# %%
query = str(input("Ingresa la palabra a buscar: "))
ranked_docs = rank_documents(query)
print(f"Documentos ordenados por similitud con la consulta '{query}':")
for doc, score in ranked_docs:
    print(f"{doc}: {score}")
# Out:
# Documentos ordenados por similitud con la consulta 'cifras':
# Don_Quijote.txt: 0.016459826252429456
# La_casa_e_la_famiglia_di_Masaniello.txt: 0.016529453326237533
# Geschiedenis_der_Noordsche_Compagnie.txt: 0.020794327611582165
# Noli_Me_Tangere.txt: 0.032256556091244434
# Ang_Filibusterismo_Karugtóng_ng_Noli_Me_Tangere.txt: 0.032717029955072766
# Romeo_and_Juliet.txt: 0.060035677580618535
# The_Complete_Works_of_William_Shakespeare.txt: 0.061343348158907254
# Tractatus Logico-Philosophicus.txt: 0.06377605590635833
# The_Blue_Castle_a_novel.txt: 0.06579234852946171
# The_Importance_of_Being_Earnest_A_Trivial_Comedy_for_Serious_People.txt: 0.0672868626914898
# Anne_of_Green_Gables.txt: 0.07015290351777582
# Crime_and_Punishment.txt: 0.07093944175726419
# WinniethePooh.txt: 0.07119607076018954
# Notes_from_the_Underground.txt: 0.07131024592472482
# A_Room_with_a_View.txt: 0.07142051621050313
# A_Dolls_House__a_play.txt: 0.0714820488433844
# Don_Juan.txt: 0.0715287895237159
# The_divine_comedy.txt: 0.07206208844733245
# Middlemarch.txt: 0.07206697875250727
# The_Brothers_Karamazov.txt: 0.072903534661769
# Jane_Eyre_An_Autobiography.txt: 0.07369761919688751
# The_Great_Gats.txt: 0.07416974441774235
# Wuthering_Heights.txt: 0.07417636524489103
# Peter_Pan.txt: 0.07429036846176953
# The_Enchanted_April.txt: 0.07450979451889903
# Calculus Made Easy.txt: 0.07480465325986557
# Pride_and_Prejudice.txt: 0.07488227738333612
# Cranford.txt: 0.07520701202159696
# Great_Expectations.txt: 0.07578928629498599
# Little_Women.txt: 0.07591549504061491
# Little_Women_Or_Meg_Jo_Beth_and_Amy.txt: 0.0759436516635235
# The_Picture_of_Dorian_Gray.txt: 0.07675131873027044
# Cookery_and_Dining_in_Imperial_Rome.txt: 0.07684187429542455
# Ulysses.txt: 0.07728082743320366
# Dracula.txt: 0.0777728369911683
# History_of_Tom_Jones_a_Foundling.txt: 0.07803022540772804
# The_Romance_of_Lust_A_classic_Victorian_erotic_novel.txt: 0.07810443996615615
# Metamorphosis.txt: 0.0792802537387841
# The_Adventures_of_Sherlock_Holmes.txt: 0.07950120758652668
# The_Adventures_of_Tom_Sawyer_Complete.txt: 0.08044813207002342
# The_Hound_of_the_Baskervilles.txt: 0.08064147637975126
# The_Adventures_of_Roderick_Random.txt: 0.081211620810545
# Come_Hither_A_Collection_of_Rhymes_and_Poems_for_the_Young_of_All_Ages_1295.txt: 0.08123336650758235
# A_Christmas_Carol_in_Prose_Being_a_Ghost_Story_of_Christmas.txt: 0.08151367316736219
# Thus_Spake_Zarathustra_A_Book_for_All_and_None.txt: 0.08151806952702254
# Twenty_years_after.txt: 0.08217747110205169
# Adventures_of_Huckleberry_Finn.txt: 0.08239097094948276
# The_Yellow_Wallpaper.txt: 0.08240867344656104
# A_Study_in_Scarlet.txt: 0.08250853145012872
# Heart_of_Darkness.txt: 0.082886936970578
# Dubliners.txt: 0.08298580772461703
# The_Odyssey.txt: 0.08391798756104257
# The_poems_of_Heine_Complete.txt: 0.08394681396062725
# Alices_Adventures_in_Wonderland.txt: 0.08457988986904012
# The_Count_of_Monte_Cristo.txt: 0.08459844512625572
# Frankenstein; Or, The Modern Prometheus.txt: 0.08568050420822197
# Frankenstein_Or_The_Modern_Prometheus.txt: 0.08568050420822197
# Plotinos_Complete_Works_v_4.txt: 0.08598769667639192
# A_Tale_of_Two_Cities.txt: 0.08635829954656936
# Don_Quixote.txt: 0.08683065402092854
# 20_hrs_40_min_.txt: 0.08710311532386361
# The_Expedition_of_Humphry_Clinker.txt: 0.08726413943815743
# War_and_Peace.txt: 0.08758088814605827
# Treasure_Island.txt: 0.08808856363149377
# Mo.txt: 0.08848820684269088
# The_Mysteries_of_London_v_14.txt: 0.08956043039375772
# The_Native_Races_of_the_Pacific_states_Volume_1_Wild_Tribes.txt: 0.08958574486303904
# The_Scarlet_Letter.txt: 0.08968941717329719
# The_Strange_Case_of_Dr_Jekyll_and_Mr_Hyde.txt: 0.090892512091302
# My_Life__Volume_1.txt: 0.09128537456687336
# Walden_and_On_The_Duty_Of_Civil_Disobedience.txt: 0.09129650429048977
# Memoirs_of_a_London_doll.txt: 0.09164459097046689
# A_Modest_Proposal.txt: 0.09169099778896497
# The_starstealers.txt: 0.09195419723446646
# The_Reign_of_Greed.txt: 0.09212840806134064
# The_Prince.txt: 0.09351570853684418
# The_Adventures_of_Ferdinand_Count_Fathom__Complete.txt: 0.09451445632078803
# The_Wonderful_Wizard_of_Oz.txt: 0.0973226027484852
# Grimms_Fairy_Tales.txt: 0.09736589130870539
# Second_Treatise_of_Government.txt: 0.09866273661827035
# Christina_of_Denmark_Duchess_of_Milan_and_Lorraine_15221590.txt: 0.09924468988642267
# The_Iliad.txt: 0.09994512329109527
# The_Philippines_a_Century_Hence.txt: 0.10509472544606259
# The_Metamorphoses_of_Ovid_Books_VIIIXV.txt: 0.10529404249094516
# The_Science_and_Philosophy_of_the_Organism.txt: 0.10557326758701174
# Sketches_and_Studies_in_Italy_and_Greece_Complete.txt: 0.10610546144604278
# Up_the_Orinoco_and_down_the_Magdalena.txt: 0.10661185394057399
# Leviathan.txt: 0.10745515617269875
# The_Kama_Sutra_of_Vatsyayana.txt: 0.10848477771877744
# The_History_of_Rome_Books_27_to_36.txt: 0.10939556496330509
# The_History_of_Rome_Books_09_to_26.txt: 0.11135615900686067
# The_Souls_of_Black_Folk.txt: 0.11206342110716634
# The_Scottish_Highlands_Highland_Clans_and_Highland_Regiments_Volume_1_of_2_550.txt: 0.1127454836157791
# Magazine_of_western_history_illustrated_Vol_I_No_1_November_1884.txt: 0.11593155519392881
# Thirty_Years_View_Vol_2_of_2.txt: 0.1177889095511401
# The_loyalists_of_America_and_their_times_.txt: 0.11969689022952922
# The_Scottish_Highlands_Highland_Clans_and_Highland_Regiments_Volume_2_of_2_1719.txt: 0.11990637351892135
# The_Christ_Myth.txt: 0.12200219348901796
# The_Empire_and_the_Papacy_9181273.txt: 0.12501053423365366
# The_story_of_Hungary.txt: 0.125976054101808

# %% [markdown]
# ### Step 3: Binary Independence Model (BIM)
#
# Task: Implement a basic Binary Independence Model to rank documents.
#
# Requirements:
# * _Binary Representation:_ Represent the corpus and the query in binary vectors (1 if the term is present, 0 otherwise).
# * _Probability Estimation:_ Assume arbitrary probabilities for the presence of each term in relevant and non-relevant documents.
# * _Relevance Scoring:_ Calculate the relevance score for each document based on the product of probabilities for terms present in the query.
# * _Ranking:_ Rank the documents based on their relevance scores from highest to lowest.
